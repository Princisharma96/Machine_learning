# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mlt
# %matplotlib inline
from sklearn import preprocessing

# %%
df = pd.read_csv('titanic.csv')
dat = df.head(10)
dat
# Out:
#    Unnamed: 0  PassengerId  Survived  Sex     Age      Fare  Pclass_1  \
# 0         791          792         0    1  0.2000  0.050749         0
# 1         792          793         0    0  0.3500  0.135753         0
# 2         793          794         0    1  0.3500  0.059914         1
# 3         794          795         0    1  0.3125  0.015412         0
# 4         795          796         0    1  0.4875  0.025374         0
# 5         796          797         1    0  0.6125  0.050610         1
# 6         797          798         1    0  0.3875  0.016949         0
# 7         798          799         0    1  0.3750  0.014110         0
# 8         799          800         0    0  0.3750  0.047138         0
# 9         800          801         0    1  0.4250  0.025374         0
#
#    Pclass_2  Pclass_3  Family_size  Title_1  Title_2  Title_3  Title_4  Emb_1  \
# 0         1         0          0.0        1        0        0        0      0
# ...

# %%
mlt.figure(figsize=(10,3))
corr=df.corr()
sns.heatmap(corr)

# %%
sns.pairplot(df , kind = 'reg')
mlt.title('Pair Plot')
sns.despine()

# %% [markdown]
# -x'=x-x.mean()/x.std()

# %%
x_train= np.array([[1. ,-1. , 2.],[2. ,0. ,0. ],[1. ,-1. ,0. ]])
x_scaled=preprocessing.scale(x_train)
x_scaled
# Out:
# array([[-0.70710678, -0.70710678,  1.41421356],
#        [ 1.41421356,  1.41421356, -0.70710678],
#        [-0.70710678, -0.70710678, -0.70710678]])

# %%
x_train= np.array([[0.1426,1.5,.78],[1.33, .98, -.25],[1.938, 8.00, -1.73]])
x_minmax=x_train - x_train.min()/x_train.max()-x_train.min()
x_minmax
# Out:
# array([[2.08885, 3.44625, 2.72625],
#        [3.27625, 2.92625, 1.69625],
#        [3.88425, 9.94625, 0.21625]])

# %%
x_train= np.array([[0.1426,21.5,.78],[1.33, 76.98, -3.25],[41.938, 8.00, -1.73]])
x_norm=x_train - x_train.mean()/x_train.max()-x_train.min()
x_norm
# Out:
# array([[ 3.18231363, 24.53971363,  3.81971363],
#        [ 4.36971363, 80.01971363, -0.21028637],
#        [44.97771363, 11.03971363,  1.30971363]])

# %%
dt=dat[['Survived','Age','Fare']]
dt.head()
dt
# Out:
#    Survived     Age      Fare
# 0         0  0.2000  0.050749
# 1         0  0.3500  0.135753
# 2         0  0.3500  0.059914
# 3         0  0.3125  0.015412
# 4         0  0.4875  0.025374
# 5         1  0.6125  0.050610
# 6         1  0.3875  0.016949
# 7         0  0.3750  0.014110
# 8         0  0.3750  0.047138
# 9         0  0.4250  0.025374

# %%
dt_minmax = dt - dt.max() / dt.max() - dt.min()
dt_minmax
# Out:
#    Survived     Age      Fare
# 0      -1.0 -1.0000 -0.963362
# 1      -1.0 -0.8500 -0.878358
# 2      -1.0 -0.8500 -0.954196
# 3      -1.0 -0.8875 -0.998699
# 4      -1.0 -0.7125 -0.988736
# 5       0.0 -0.5875 -0.963500
# 6       0.0 -0.8125 -0.997162
# 7      -1.0 -0.8250 -1.000000
# 8      -1.0 -0.8250 -0.966973
# 9      -1.0 -0.7750 -0.988736

# %%
dt_norm = dt - dt.mean() / dt.max() - dt.min()
dt_norm
# Out:
#    Survived       Age      Fare
# 0      -0.2 -0.632653 -0.288500
# 1      -0.2 -0.482653 -0.203496
# 2      -0.2 -0.482653 -0.279334
# 3      -0.2 -0.520153 -0.323837
# 4      -0.2 -0.345153 -0.313874
# 5       0.8 -0.220153 -0.288638
# 6       0.8 -0.445153 -0.322300
# 7      -0.2 -0.457653 -0.325138
# 8      -0.2 -0.457653 -0.292111
# 9      -0.2 -0.407653 -0.313874

# %%
x_scaled=preprocessing.scale(dt)
x_scaled
# Out:
# array([[-0.5       , -1.82169813,  0.191568  ],
#        [-0.5       , -0.36433963,  2.65498681],
#        [-0.5       , -0.36433963,  0.45718734],
#        [-0.5       , -0.72867925, -0.8325015 ],
#        [-0.5       ,  0.97157234, -0.54378089],
#        [ 2.        ,  2.18603775,  0.18756318],
#        [ 2.        ,  0.        , -0.78795632],
#        [-0.5       , -0.12144654, -0.87020793],
#        [-0.5       , -0.12144654,  0.0869222 ],
#        [-0.5       ,  0.36433963, -0.54378089]])

# %%
dt_minmax = dt - dt.min() / dt.max() - dt.min()
dt_minmax
# Out:
#    Survived       Age      Fare
# 0       0.0 -0.326531 -0.067304
# 1       0.0 -0.176531  0.017700
# 2       0.0 -0.176531 -0.058139
# 3       0.0 -0.214031 -0.102641
# 4       0.0 -0.039031 -0.092679
# 5       1.0  0.085969 -0.067443
# 6       1.0 -0.139031 -0.101104
# 7       0.0 -0.151531 -0.103942
# 8       0.0 -0.151531 -0.070915
# 9       0.0 -0.101531 -0.092679

# %%
dat['Fare'].plot(kind="kde")

# %%
c= np.power(dat['Fare'],1/3)
c.plot(kind="kde")

# %%
c= np.power(dat['Fare'],1/2)
c.plot(kind="kde")

# %%
c= np.log(dat['Fare'])
c.plot(kind="kde")

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
df_num = dt[['Age','Fare']]
selector= VarianceThreshold(0.01)
a= selector.fit_transform(df_num)
a
# Out:
# array([[0.2   ],
#        [0.35  ],
#        [0.35  ],
#        [0.3125],
#        [0.4875],
#        [0.6125],
#        [0.3875],
#        [0.375 ],
#        [0.375 ],
#        [0.425 ]])

# %%
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
iris= load_iris()
x, y=iris.data, iris.target
x_new=SelectKBest(chi2, k=2).fit_transform(x, y)
x.shape,x_new.shape
# Out:
# ((150, 4), (150, 2))

# %%
df_num
# Out:
#       Age      Fare
# 0  0.2000  0.050749
# 1  0.3500  0.135753
# 2  0.3500  0.059914
# 3  0.3125  0.015412
# 4  0.4875  0.025374
# 5  0.6125  0.050610
# 6  0.3875  0.016949
# 7  0.3750  0.014110
# 8  0.3750  0.047138
# 9  0.4250  0.025374

# %%
a.ndim
# Out:
# 2
