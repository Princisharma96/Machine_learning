# %% [markdown]
# # Exploratory Data Analysis on House Price Prediction
# The aim of this report is to predict the house prices based on various parameters. Our main objective here is to define a report consisting of Data Visualisation using various libraries like Seaborn and Matplotlib. Here, we will visualise and predict the house sales using the test data.
#
# The parameters used in this data set are very general and relatable. The various parameters considered in this data set are- the condition of the house, the location of the house, what is the actual market value, how many bedrooms does it have etc.

# %% [markdown]
# ### Attribute Information
# The various attributes on which the data is observed are:
#
# Date it was bought on
# The market value
# Number of bedrooms
# Number of bathrooms
# The living area in sqft
# The lot area in sqft
# The condition of the house
# The year it was built in
# The year it was renovated in
# The zipcode of the area
# The latitude
# The longitude
# And many more parameters which we will observe and analyse in this report.

# %%
# Importing the required libraries:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mlt
# %matplotlib inline

# %%
# Let us view the data in a dataframe format.
# We use the head function to view the first ten rows of the data set.
df = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv')
df = df.head(10)
df
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# ...

# %%
#We will now describe the data set using the describe function which tells us about the statistical data related to the data set
df.describe()
# Out:
#                  id         price   bedrooms  bathrooms  sqft_living  \
# count  1.000000e+01  1.000000e+01  10.000000  10.000000    10.000000
# mean   4.039155e+09  4.380750e+05   3.100000   2.100000  2002.500000
# std    2.331445e+09  3.137603e+05   0.567646   1.094177  1305.367658
# min    1.321400e+09  1.800000e+05   2.000000   1.000000   770.000000
# 25%    2.109650e+09  2.365000e+05   3.000000   1.125000  1305.000000
# 50%    3.140351e+09  3.074250e+05   3.000000   2.125000  1747.500000
# 75%    6.218450e+09  5.310000e+05   3.000000   2.437500  1942.500000
# max    7.237550e+09  1.225000e+06   4.000000   4.500000  5420.000000
#
#             sqft_lot     floors  waterfront  view  condition      grade  \
# count      10.000000  10.000000        10.0  10.0  10.000000  10.000000
# mean    16846.200000   1.300000         0.0   0.0   3.200000   7.400000
# std     29937.105556   0.483046         0.0   0.0   0.632456   1.349897
# ...

# %%
# We will now check if our data set contains any null values or not
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# This shows that there is no null value present in the data set

# %%
mlt.figure(figsize = (8,3))
sns.countplot(x = 'bedrooms', data= df)

# %% [markdown]
# # Univariate Analysis
# 'Uni' stands for One. This means that the analysis is done considering one variable.
# This is the simplest method of analysis.
# Univariate analysis is used to describe the data and observe the pattern.
# Hence, it is also helpful during the bivariate or multivariate analysis.

# %%
mlt.boxplot(df.price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x274f0596f98>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x274f059f898>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x274f0596e48>],
#  'medians': [<matplotlib.lines.Line2D at 0x274f046d128>],
#  'fliers': [<matplotlib.lines.Line2D at 0x274f046d550>],
#  'means': []}

# %%
mlt.hist(x ='price', data = df)
sns.despine()

# %%
sns.kdeplot(df.price)

# %%
mlt.hist(x='price', data=df , bins=20)
sns.despine()

# %%
sns.distplot(df.bathrooms)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.countplot(x='bedrooms', data= df)
sns.despine()

# %%
sns.boxplot(data = df['price'])

# %%
sns.countplot(x = 'floors', data = df)
sns.despine()

# %%
sns.distplot(df['yr_built'])
sns.despine()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['sqft_living15'])
sns.despine()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # Bivariate Analysis
# 'Bi' stands for Twp. This means that the analysis is done considering two variables. It is the simultaneous analysis of two variables. It tells us about the dependencies, association and relation between these two specific variables. After analysing their relation, we can infer the level of their dependencies on each other.

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000  0.367985  0.004542   0.182635     0.423402  0.477555
# price          0.367985  1.000000  0.755438   0.909927     0.938850  0.870373
# bedrooms       0.004542  0.755438  1.000000   0.787127     0.690895  0.523618
# bathrooms      0.182635  0.909927  0.787127   1.000000     0.876234  0.752348
# sqft_living    0.423402  0.938850  0.690895   0.876234     1.000000  0.907429
# sqft_lot       0.477555  0.870373  0.523618   0.752348     0.907429  1.000000
# floors        -0.058058 -0.143489 -0.121566   0.147157     0.029516 -0.229872
# waterfront          NaN       NaN       NaN        NaN          NaN       NaN
# view                NaN       NaN       NaN        NaN          NaN       NaN
# condition     -0.233890  0.185811  0.557086   0.289010    -0.011440 -0.139036
# grade          0.321854  0.912328  0.667017   0.797398     0.919351  0.930458
# ...

# %% [markdown]
# We analyse the co-relation between all the considered parameters

# %% [markdown]
# We use heatmap to plot the relation between the various parameters. The positive values show direct relation whereas the negative values represent opposite or indirect relation

# %%
mlt.figure(figsize = (10,8))
sns.heatmap(df.corr())
mlt.show()

# %%
sns.regplot(x = 'bedrooms',y = 'price',data = df)
sns.despine()

# %% [markdown]
# Regression plot for bedrooms vs price

# %%
mlt.figure(figsize=(8,4))
sns.barplot(x = 'floors',y = 'price', data=df, hue='sqft_living' )

# %%
mlt.figure(figsize=(8,3))
sns.kdeplot(data= df.price, data2= df.bathrooms)

# %%
mlt.figure(figsize=(8,7))
sns.boxplot(x ='sqft_living15', y='price', data=df.head(20))

# %%
mlt.figure(figsize=(10,8))
sns.boxplot(x='sqft_living', y= 'price', data=df)

# %%
mlt.figure(figsize=(10,8))
sns.swarmplot(x= 'sqft_living', y='price', data= df,hue='bathrooms')

# %%
mlt.figure(figsize=(8,7))
sns.lmplot(x ="sqft_living",y="price", data = df,hue = "bedrooms")

# %%
sns.pairplot(df)

# %% [markdown]
# # # final plot

# %% [markdown]
# the 3 most favourite graphs are:
#
# 1.Implot showing the yr_built and price for each bedroom

# %%
mlt.figure(figsize=(8,6))
sns.lmplot(x ="yr_built",y="price", data = df,hue = "bedrooms")

# %% [markdown]
# 2.boxplot between bedrooms and price as it gives us the maximum relation between them

# %%
mlt.figure(figsize=(9,8))
sns.boxplot(x='bedrooms', y= 'price', data=df)

# %% [markdown]
# 3.heatmap as it shows the correlation between different components of house price

# %%
mlt.figure(figsize = (10,8))
sns.heatmap(df.corr())
mlt.show()
